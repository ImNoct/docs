# %% [markdown]
# TODO:
#
# - код сбора ссылок на страницы с элементом
#
# - как обработать html страницу?!

# %%
import re
import PyPDF2

# %%
# пример чтения текста pdf

path = '/home/admen/Desktop/pdf/Примеры документов/ИВУА.468352.007ПЭ3.pdf'

pdfFileObj = open(path, 'rb')
 
pdfReader = PyPDF2.PdfReader(pdfFileObj)
 
print(len(pdfReader.pages))
 
for page in pdfReader.pages:
    print(page.extract_text())
 
pdfFileObj.close()
# Out:
# 4
#
#  Перв. примен.
# ИВУА.468352.007  Справ. №
#
#  Подп. и дата
#  Инв. № дубл.
#  Взам. инв. №
#  Подп. и дата
#  Инв. № подл.
#
#
#      ИВУА.468352.007ПЭ3
# Изм. Лист № докум.  Подп. Дата
# Разраб.  Буров  27.02.1
# 4 Модуль ИУ
# Перечень элементов  Лит. Лист Листов
# Пров. Голосов       1 4
#
#  Н. контр.  Константинов
# а
# Утв. Майков   Поз.
# обозначе -
# ние Наименование  Кол. Примечание
#  Конденсаторы
# C1 C3216X5R1E476M160AC  TDK 1 1206-X5R-47 мкФ±20% -25В
# C2 C1005X5R1C224K050BB  TDK 1 0402-X5R-0,22 мкФ±10% -16В
#
#  Микросхемы АЕЯР.431230.627 ТУ
# DD1 1554ЛЛ1ТБМ  1
#
#  Резисторы Р1 -12 АЛЯР.434110.005 ТУ
# R1...R8 Р1-12-0,062-1 кОм±5% -М-"A" 8
# R9 Р1-12-0,125-180 Ом±5% -М-"A" 1
# R10 Р1-12-0,125-390 Ом±5% -М-"A" 1
# R11 Р1-12-0,125-180 Ом±5% -М-"A" 1
# R12 Р1-12-0,125-390 Ом±5% -М-"A" 1
# R13 Р1-12-0,125-180 Ом±5% -М-"A" 1
# R14 Р1-12-0,125-390 Ом±5% -М-"A" 1
# R15 Р1-12-0,125-180 Ом±5% -М-"A" 1
# R16 Р1-12-0,125-390 Ом±5% -М-"A" 1
# ...

# %%
# пример списка элементов из файлов:
    # Примеры документов/ИВУА.467139.001ПЭ3.pdf
    # Примеры документов/ИВУА.468157.015ПЭ3.pdf
    # Примеры документов/ИВУА.468352.007ПЭ3.pdf
    # Примеры документов/ПЭ3_Пример.pdf

# Было бы удобно в примерно таком формате как в этих доках: 
    # обознаение остальная инфа (все в одной строке)
s = """Конденсаторы    
C1 T495E107M025ATE100 Kemet  1 E-100 мкФ±20% -25В 
C2 C1608X5R1E105K080 AC TDK  1 0603-X5R-1 мкФ±10% -25В 
C3 T495E107M025ATE100 Kemet  1 E-100 мкФ±20% -25В 
C4, C5 C2012X5R1C226M125AC TDK  2 0805-X5R-22 мкФ±20% -16В 
C6, C7 C1005X5R1C10 5K050BC TDK  2 0402-X5R-1 мкФ±10% -16В 
C8, C9 C2012X5R1A476M125AC TDK  2 0805-X5R-47 мкФ±20% -10В 
C10...C21  C0510X5R1C104M030AC TDK  12 0204-X5R-0,1 мкФ±20% -16В 
Р1-12-0,125-180 Ом±5% -М-"A" 1  
R40 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R41 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R42 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R43 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R44 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R45 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R46 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R47 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R48 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R49 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R50 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R51 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R52 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R53 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R54 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R55 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R56 Р1-12-0,125-390 Ом±5% -М-"A" 1 
R57 Р1-12-0,125-180 Ом±5% -М-"A" 1  
R58 Р1-12-0,125-390 Ом±5% -М-"A" 1  
R59...R61  Р1-12-0,062-4,7 кОм±5% -М-"A" 3  
R62...R66  Р1-12-0,1-560 Ом±5% -М-"A" 5  
    
 Полупроводниковые приборы    
VD1...VD5  Индикатор единичный  ИПД14Ж -Л/ПО АЕЯР.432220.408  ТУ 5  
VT1...VT5  Транзистор PDTC143ET NXP (Philips)  5  
    
 Соединители    
XP1 Вилка СНП333-62ВП32 -1-В РЮМК.430420.010ТУ  1 DHR-62M 
XS1 Розетка СНП333-44РП32 -3-В РЮМК.430420.010ТУ  1 DHR-44F 
XS2 Розетка СНП260-135РП32 БСАР.434410.003 ТУ  1  

Конденсаторы
C1,C2 К10-83-16 В-0,1 мкФ±10 %-Н30 АЖЯР.673511.008ТУ 2
C3...C12 К58-26-2,7 В-100 Ф±20 % ЕВАЯ.673811.006ТУ 10
C13 К50-94 «C»-160 В-220 мкФ±20 % АЖЯР.673541.007ТУ 1
C14 К50-85 «C»-25 В-1000 мкФ±20 % АЖЯР.673541.014ТУ 1

Микросхемы
DA1  1467СА4ТБМ ОАО «Интеграл» 1
DA2  К1290ЕФ1Х НТЦ СИТ 1

Резисторы
R1 ОСМ Р1-12-0,1-1,3 кОм±5 % ТАЛЯР.434110.005ТУ РД В 22.02.218 1
R2 ОСМ Р1-12-0,1-2,2 кОм±5 % ТАЛЯР.434110.005ТУ РД В 22.02.218 1
R3 ОСМ Р1-12-0,1-10 кОм±5 % ТАЛЯР.434110.005ТУ В РД В 22.02.218 1
R4 ОСМ Р1-12-0,1-3 кОм±5 % ТАЛЯР.434110.005ТУ В РД В 22.02.218 1 """

# %%
# element text to dict
def parse_elem(line, last_group, group_info):
    record = {}

    # Label
    # DD00 ... DD99 
    # DD00 , DD99 
    # DD00    
    label_patterns = [r'^\s*[A-Z]{1,2}[0-9]{1,2}\s*\.+\s*[A-Z]{1,2}[0-9]{1,2}\s+', 
                      r'^\s*[A-Z]{1,2}[0-9]{1,2}\s*\,\s*[A-Z]{1,2}[0-9]{1,2}\s+', 
                      r'^\s*[A-Z]{1,2}[0-9]{1,2}\s+']
    
    for pattern in label_patterns:
        x = re.search(pattern, line)
        if x:
            break
    if x:
        record["label"] = x.group(0).strip()
        line = line[x.end():]
        
    # Amount of elements
    x = re.search(r'\s+[0-9]+(\s+|$)', line)
    if x:
        record["amount"] = x.group(0).strip()
        line = line[:x.start()] + ' ' + line[x.end():]
    
    # All that left in string
    record["info"] = line

    series_pattern = r'(\s+|^)([А-Яа-яЁё]+\s+)*(?=[A-Za-zА-Яа-яЁё]*(\d|\.))(?=\d*([A-Za-zА-Яа-яЁё]|\.))[A-Za-zА-Яа-яЁё0-9\.]{4,}(\s+|$)'
    x = re.search(series_pattern, line)
    if x:
        record["series"] = x.group(0).strip()
    else:
        x = re.search(series_pattern, group_info)
        if x:
            record["series"] = x.group(0).strip()
        else:
            record["series"] = ''
            print("NO SERIES FOUND", line)
        
    record["group"] = last_group
    record["group_info"] = group_info
    
    if not record:
        raise Exception("Cant parse line as element record")
    
    return record

# %%
info = []

last_group = ""
group_info = ""

for line in s.split("\n"):
    if not line.strip():
        last_group = ""
        group_info = ""
        continue

    # Название группы    
    x = re.search('^\s*([A-Za-zА-Яа-яЁё]+(\s+|$))+', line)
    if x:
        last_group = x.group(0).strip()
        group_info = line[x.span()[1]:].strip()
        continue
    
    # Строка с элементом
    record = parse_elem(line, last_group, group_info)
    if record:
        info.append(record)
        
        
info
# for i in info:
    # print(i["series"])
# Out:
# NO SERIES FOUND Светодиод KPT -1608SGC Kingbright
# NO SERIES FOUND Вилка M50 -3502542  Harwin
# NO SERIES FOUND Фильтр LFCN -120 Mini -Circuits
# NO SERIES FOUND Вилка DRB -37M
# NO SERIES FOUND Вилка M50 -3502542  Harwin
# NO SERIES FOUND Фильтр LFCN -120 Mini -Circuits
# [{'label': 'C1',
#   'amount': '1',
#   'info': 'T495E107M025ATE100 Kemet E-100 мкФ±20% -25В ',
#   'series': 'T495E107M025ATE100',
#   'group': 'Конденсаторы',
#   'group_info': ''},
#  {'label': 'C2',
#   'amount': '1',
#   'info': 'C1608X5R1E105K080 AC TDK 0603-X5R-1 мкФ±10% -25В ',
#   'series': 'C1608X5R1E105K080',
#   'group': 'Конденсаторы',
#   'group_info': ''},
#  {'label': 'C3',
#   'amount': '1',
#   'info': 'T495E107M025ATE100 Kemet E-100 мкФ±20% -25В ',
#   'series': 'T495E107M025ATE100',
#   'group': 'Конденсаторы',
#   'group_info': ''},
#  {'label': 'C4, C5',
#   'amount': '2',
#   'info': 'C2012X5R1C226M125AC TDK 0805-X5R-22 мкФ±20% -16В ',
#   'series': 'C2012X5R1C226M125AC',
# ...

# %%
# для серийных номеров (можно удалить)

# ([А-Яа-яЁё]+\s+)*\b(?=[A-Za-zА-Яа-яЁё]*(\d|\.))(?=\d*([A-Za-zА-Яа-яЁё]|\.))[A-Za-zА-Яа-яЁё0-9\.]{4,}\b\s+([A-Za-zА-Яа-яЁё]+\s*)*
# (\s+|^)([А-Яа-яЁё]+\s+)*(?=[A-Za-zА-Яа-яЁё]*(\d|\.))(?=\d*([A-Za-zА-Яа-яЁё]|\.))[A-Za-zА-Яа-яЁё0-9\.]{4,}\s+([A-Za-zА-Яа-яЁё]+(\s+|$))*
# (\s+|^)([А-Яа-яЁё]+\s+)*(?=[A-Za-zА-Яа-яЁё]*(\d|\.))(?=\d*([A-Za-zА-Яа-яЁё]|\.))[A-Za-zА-Яа-яЁё0-9\.]{4,}\s+

# %%
# все возможные обозначения элементов http://www.pntd.ru/2.710.htm
labels = {}

with open('labels.txt') as file:
    for line in file:
        if not line.strip():
            continue

        line = line.split()

        short_name = line[-1]
        line = " ".join(line[:-1])
        labels[short_name] = line

# print(d)
labels
# Out:
# {'А': 'Устройство (общее обозначение)',
#  'B': 'Преобразователи неэлектрических величин в электрические (кроме генераторов и источников питания) или наоборот аналоговые или многозарядные преобразователи или датчики для указания или измерения',
#  'ВА': 'Громкоговоритель',
#  'ВВ': 'Магнитострикционный элемент',
#  'BD': 'Детектор ионизирующих излучений',
#  'BE': 'Сельсин-приемник',
#  'BF': 'Телефон (капсюль)',
#  'BC': 'Сельсин-датчик',
#  'BK': 'Тепловой датчик',
#  'BL': 'Фотоэлемент',
#  'BM': 'Микрофон',
#  'BP': 'Датчик давления',
#  'BQ': 'Пьезоэлемент',
#  'BR': 'Датчик частоты вращения (тахогенератор)',
#  'BS': 'Звукосниматель',
#  'BV': 'Датчик скорости',
#  'C': 'Конденсаторы',
#  'D': 'Схемы интегральные, микросборки',
#  'DA': 'Схема интегральная аналоговая',
#  'DD': 'Схема интегральная, цифровая, логический элемент',
#  'DS': 'Устройства хранения информации',
#  'DT': 'Устройство задержки',
#  'Е': 'Элементы разные',
#  'ЕК': 'Нагревательный элемент',
# ...

# %%
# Запросы ко вселенной

# pip install google

# %%
info = [{'label': 'C1',
  'amount': '1',
  'info': 'T495E107M025ATE100 Kemet E-100 мкФ±20% -25В ',
  'series': 'T495E107M025ATE100',
  'group': 'Конденсаторы',
  'group_info': ''},
 {'label': 'C2',
  'amount': '1',
  'info': 'C1608X5R1E105K080 AC TDK 0603-X5R-1 мкФ±10% -25В ',
  'series': 'C1608X5R1E105K080',
  'group': 'Конденсаторы',
  'group_info': ''},
 {'label': 'C3',
  'amount': '1',
  'info': 'C0805C473K5RACTU Kemet',
  'series': 'C0805C473K5RACTU',
  'group': 'Конденсаторы',
  'group_info': ''}]

# %%
try:
    from googlesearch import search
except ImportError:
    print("No module named 'google' found")

# %%
# Запросы в гугл с серией элемента
# - лучше на русском языке?
# - как ставить задержки чтоб не забанили за кол-во запросов?
# - сколько нужно страниц и как забирать оттуда текст с информацией?
for i in info:
    q = 'конденсатор ' + i['series']
    print(q)

    for j in search(q, tld="co.in", num=10, stop=10, pause=2):
        print(j)
# Out:
# конденсатор T495E107M025ATE100
# https://www.mouser.com/ProductDetail/KEMET/T495E107M025ATE100?qs=5BlHYZRUXHH5E3L4jw8png%3D%3D
# https://www.chipdip.am/product/t495e107m025ate100
# https://www.digikey.at/en/products/detail/kemet/T495E107M025ATE100/9642270
# https://neocomponent.com/t495e107m025ate100_399_18856_2_nd/
# https://www.promelec.ru/product/10166726/
# https://www.digikey.com/en/products/detail/kemet/T495E107M025ATE100/9642270
# https://neocomponent.com/kondensatory5152247/?page=1306
# https://fi.farnell.com/en-FI/kemet/t495e107m025ate100/cap-100uf-25v-tant-case-e/dp/4071556
# https://smartcart.megabonus.com/item/108483351-t491d106m025at-kemet-kupit-v-roznitsu-i-optom
# https://zapadpribor.com/t495a156k006a-t495b156k016ate-201/
# конденсатор C1608X5R1E105K080
# конденсатор T495E107M025ATE100
# https://www.mouser.com/ProductDetail/KEMET/T495E107M025ATE100?qs=5BlHYZRUXHH5E3L4jw8png%3D%3D
# https://www.chipdip.am/product/t495e107m025ate100
# ...

# %%
# вариант 2
import requests, json, lxml
from bs4 import BeautifulSoup

# https://docs.python-requests.org/en/master/user/quickstart/#passing-parameters-in-urls
query = 'конденсатор C0805C473K5RACTU Kemet'
params = {
    "q": query,          # query example
    "hl": "ru",          # language
    "gl": "ru",          # country of the search, UK -> United Kingdom
    "start": 0,          # number page by default up to 0
    #"num": 100          # parameter defines the maximum number of results to return.
}

# https://docs.python-requests.org/en/master/user/quickstart/#custom-headers
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"
}

page_limit = 1          # page limit if you don't need to fetch everything
page_num = 0

data = []

while True:
    page_num += 1
    print(f"page: {page_num}")

    html = requests.get("https://www.google.com/search", params=params, headers=headers, timeout=30)
    soup = BeautifulSoup(html.text, 'lxml')

    for result in soup.select(".tF2Cxc"):
        title = result.select_one(".DKV0Md").text
        try:
           snippet = result.select_one(".VwiC3b span").text
        except:
           snippet = None
        links = result.select_one(".yuRUbf a")["href"]

        data.append({
          "title": title,
          "snippet": snippet,
          "links": links
        })

    # stop loop due to page limit condition
    if page_num == page_limit:
        break
    # stop the loop on the absence of the next page
    if soup.select_one(".d6cvqb a[id=pnnext]"):
        params["start"] += 10
    else:
        break
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# page: 1
# [
#   {
#     "title": "C0805C473K5RACTU, Конденсатор керамический SMD ...",
#     "snippet": "C0805C473K5RACTU, Конденсатор керамический SMD (0805 X7R 0,047мкФ 50В 10%) · Производитель: Kemet · В наличии · Самовывоз через в течение 1 дня · Отправка возможна ...",
#     "links": "https://oao-sozvezdie.ru/catalog/kondensatory_keramicheskie_smd/c0805c473k5ractu_kondensator_keramicheskiy_smd_0805_x7r_0047mkf_50v_10/"
#   },
#   {
#     "title": "Kemet Electronics - Керамический чип-конденсатор",
#     "snippet": "Купить C0805C473K5RACTU , Kemet Electronics, Керамический чип-конденсатор SMD 0805, цена , datasheet, доставка по России, самовывоз бесплатно, наличие, ...",
#     "links": "https://www.elmatrix.ru/catalog/18934/"
#   },
#   {
#     "title": "C0805C473K5RACTU, Конденсатор керамический SMD ...",
# ...

# %%
# яндекс просит пройти регистрацию для запросов
# или вариант: получать страницу с ответом и доставать оттуда ссылки
user_query = 'C0805C473K5RACTU Kemet'
blok_list = user_query.split()
url_query = '%20'.join(blok_list)
url = 'https://yandex.ru/search/?text=' + url_query + '&lr=213'
print(url)
# Out:
# https://yandex.ru/search/?text=C0805C473K5RACTU%20Kemet&lr=213
