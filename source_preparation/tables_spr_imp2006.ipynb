# %%
import pandas as pd

# %%
# интегральные микросхемы
# разобраться с таблицами!

# %%
# полупроводниковые приборы
path = 'tables/spr_imp2006/полупроводниковые приборы/Характеристика надежности и справочные данные отдельных групп полупроводниковых приборов.csv'
df = pd.read_csv(path)
display(df)
# Out:
#     id                                     Группа изделий  \
# 0    0                               Диоды низкочастотные
# 1    1                               Диоды низкочастотные
# 2    2                               Диоды низкочастотные
# 3    3                               Диоды низкочастотные
# 4    4                               Диоды низкочастотные
# 5    5                               Диоды низкочастотные
# 6    6                               Диоды низкочастотные
# 7    7                              Диоды высокочастотные
# 8    8                              Диоды высокочастотные
# 9    9                              Диоды высокочастотные
# 10  10                              Диоды высокочастотные
# 11  11                              Диоды высокочастотные
# 12  12                              Диоды высокочастотные
# 13  13              Транзисторы биполярные низкочастотные
# 14  14                 Транзисторы полевые низкочастотные
# ...

# %%
# оптоэлектронные полупроводниковые приборы
path = 'tables/spr_imp2006/оптоэлектронные полупроводниковые приборы/Характеристика надежности и справочные данные отдельных групп оптоэлектронных полупроводниковых приборов.csv'
df = pd.read_csv(path)
display(df)
# Out:
#     id                                     Группа изделий Подгруппа изделий  \
# 0    0      Фотоприемники транзисторные (фототранзисторы)               NaN
# 1    1                  Фотоприемники диодные (фотодиоды)               NaN
# 2    2                         Оптопары диодные единичные               NaN
# 3    3  Оптопары транзисторные единичные (включая пару...               NaN
# 4    4                     Оптопары резисторные единичные               NaN
# 5    5                          Оптопары диодные двоичные               NaN
# 6    6  Оптопары транзисторные двоичные (включая пару ...               NaN
# 7    7                      Оптопары резисторные двоичные               NaN
# 8    8           Излучающие диоды инфракрасного диапазона               NaN
# 9    9                              Светоизлучающие диоды               NaN
# 10  10                                 Сегментные дисплеи               NaN
# ...

# %%
# резисторы
path = 'tables/spr_imp2006/резисторы/Характеристика надежности и справочные данные отдельных групп резисторов.csv'
df = pd.read_csv(path)
display(df)
# Out:
#    id                                     Группа изделий  \
# 0   0  Резисторы постоянные пленочные, в т.ч. поверхн...
# 1   1     Резисторы постоянные проволочные, кроме мощных
# 2   2            Резисторы постоянные проволочные мощные
# 3   3  Сборки резисторные, в т.ч. поверхностного монтажа
# 4   4  Резисторы переменные проволочные, кроме мощных...
# 5   5   Резисторы переменные проволочные мощные (> 5 Вт)
# 6   6  Резисторы переменные проволочные полупрецизионные
# 7   7  Резисторы переменные непроволочные, кроме прец...
# 8   8    Резисторы переменные непроволочные прецизионные
# 9   9                                     Терморезисторы
#
#                                                  ОТУ  \
# 0  MIL-PRF-55182, MIL-PRF-22684, MIL-PRF-39017, M...
# 1                                      MIL-PRF-39005
# 2  MIL-PRF-26, MIL-PRF-18546, MIL-PRF-39007, MIL-...
# 3                         MIL-PRF-914, MIL-PRF-83401
# 4        MIL-PRF-27208, MIL-PRF-39015, MIL-PRF-12934
# ...

# %%
# конденсаторы
path = 'tables/spr_imp2006/конденсаторы/Характеристика надежности и справочные данные отдельных групп конденсаторов.csv'
df = pd.read_csv(path)
display(df)
# Out:
#     id                                     Группа изделий  \
# 0    0  Бумажные / с органическим синтети-ческим диэле...
# 1    1                                           Слюдяные
# 2    2                                         Стеклянные
# 3    3  Керамические постоянной ёмкости термокомпенсац...
# 4    4                    Керамические постоянной ёмкости
# 5    5  Керамические постоянной ёмкости поверхностного...
# 6    6         Керамические переменной ёмкости (триммеры)
# 7    7                          Оксидно-полупроводниковые
# 8    8   Оксидно-полупроводниковые поверхностного монтажа
# 9    9                                   Объемно-пористые
# 10  10              Оксидно-электролитические алюминиевые
# 11  11  Переменные поршневого типа трубчатые подстроечные
#
#                                                   ОТУ  \
# 0   MIL-PRF-19978, MIL-PRF-39022, MIL-PRF-55514, M...
# 1                                       MIL-PRF-39001
# ...

# %%
# трансформаторы и катушки индуктивности 
path = 'tables/spr_imp2006/трансформаторы и катушки индуктивности/Характеристика надежности и справочные данные отдельных групп трансформаторов и катушек индуктивности.csv'
df = pd.read_csv(path)
display(df)
# Out:
#    id                                     Группа изделий  \
# 0   0                                     Трансформаторы
# 1   1                                     Трансформаторы
# 2   2                                     Трансформаторы
# 3   3                                     Трансформаторы
# 4   4                                     Трансформаторы
# 5   5  Катушки индуктивности постоянные, в т.ч. для п...
# 6   6  Катушки индуктивности переменные, в т.ч. для п...
#
#                    Подгруппа изделий  \
# 0                Строчные (U < 20 В)
# 1       Звуковой частоты (15–20 кГц)
# 2          Импульсные малой мощности
# 3  Импульсные мощные (Римп ≥ 300 Вт)
# 4                     Радиочастотные
# 5                                NaN
# 6                                NaN
#
#                                            ОТУ  \
# 0                                          NaN
# 1                                   MIL-PRF-27
# 2                                MIL-PRF-21038
# ...

# %%
# коммутационные изделия
path = 'tables/spr_imp2006/коммутационные изделия/Характеристика надежности и справочные данные отдельных групп коммутационных изделий.csv'
df = pd.read_csv(path)
display(df)
# Out:
#    id                       Группа изделий λб.с.г·10^6,1/ч      Кх
# 0   0                    Переключатели DIP         0,00012    0,01
# 1   1              Переключатели кнопочные             0,1  0,0026
# 2   2              Переключатели движковые           0,023    0,003
# 3   3  Переключатели поворотные (галетные)            0,11    0,007
# 4   4         Переключатели чувствительные            0,49  0,0007
# 5   5            Переключатели термические           0,031    0,01
# 6   6  Переключатели барабанные (дисковые)            0,18    0,01
# 7   7                             Тумблеры             0,1   0,0041

# %%
# соединители
path = 'tables/spr_imp2006/соединители/Характеристика надежности и справочные данные отдельных групп соединителей.csv'
df = pd.read_csv(path)
display(df)
# Out:
#    id                                     Группа изделий λб.с.г·10^6, 1/ч  \
# 0   0                           Цилиндрические и круглые            0,001
# 1   1                             Печатные разъемы (PCB)             0,04
# 2   2                                     Гексагональные             0,15
# 3   3                                  Стоечно-панельные            0,021
# 4   4                                      Прямоугольные            0,046
# 5   5                       Высокочастотные коаксиальные          0,00041
# 6   6                                         Телефонные           0,0075
# 7   7                                             Мощные            0,007
# 8   8                                      Триаксиальные           0,0036
# 9   9  Сокеты (панельки для ИС) DIP, SIP, PGA, Chip C...          0,00064
#
#       Кх
# 0   0,10
# 1  0,051
# 2   0,02
# 3   0,02
# 4   0,02
# 5    0,30
# 6   0,02
# 7   0,02
# 8    0,3
# 9    0,01

# %%
# реле
# s = ''''''

# path = 'tables/spr_imp2006/реле/.csv'

# with open(path, 'w') as file:
#     file.write(s)

# df = pd.read_csv(path)

# df.insert(0, "id", [i for i in range(10)])
# df.to_csv(path, index=False)  
# df = pd.read_csv(path)

# display(df)

# %%
# лампы электрические
path = 'tables/spr_imp2006/лампы электрические/Характеристика надежности и справочные данные отдельных групп ламп электрических.csv'
df = pd.read_csv(path)
display(df)
# Out:
#    id       Группа изделий                                   λб.с.г·10^6, 1/ч  \
# 0   0  Лампы электрические  0,074·U^1,29, где U – номинальное напряжение л...
#
#     Кх
# 0  0,01

# %%
# приборы пьезоэлектрические

path = 'tables/spr_imp2006/приборы пьезоэлектрические/Характеристика надежности и справочные данные отдельных групп приборов пьезоэлектрических.csv'


df = pd.read_csv(path)
display(df)
# Out:
#    id                      Группа изделий           ОТУ Перечни QML и QPL  \
# 0   0  Приборы пьезоэлектрические простые  MIL-PRF-3098          QPL-3098
#
#                                  λб.с.г·10^6, 1/ч   Кх
# 0  0,013·f^0,23, где f – номинальная частота, МГц  0,01

# %%
# установочные изделия
path = 'tables/spr_imp2006/установочные изделия/Характеристика надежности и справочные данные отдельных групп установочных изделий .csv'

df = pd.read_csv(path)
display(df)
# Out:
#    id  Группа изделий                           ОТУ     Перечни QML и QPL  \
# 0   0  Предохранители  MIL-PRF-23419, MIL-PRF-15160  QPL-23419, QPL-15160
#
#   λб.с.г·10^6, 1/ч   Кх
# 0             0,01  0,03

# %%
#Sprav2006

# ТАБЛИЦЫ ДЛЯ РАСЧЕТА НАДЕЖНОСТИ 
# Таблица 6 
# Характеристика надежности отдельных групп конденсаторов

groups_spr = """Керамические на номинальное напряжение менее 1600 В
Керамические на номинальное напряжение 1600 В и выше 
Тонкопленочные с неорганическим диэлектриком 
Стеклянные
Слюдяные
Бумажные
Оксидно-электролитические
Оксидно-электролитические импульсные
Объемно-пористые
Оксидно-полупроводниковые
С органическим синтетическим диэлектриком 
    полистирольные 
    фторопластовые 
    полиэтилентерефталатные низковольтные 
    полиэтилентерефталатные высоковольтные 
    комбинированные низковольтные 
    комбинированные высоковольтные постоянного напряжения 
    комбинированные высоковольтные импульсные 
    поликарбонатные и полипропиленовые 
Подстроечные с твердым диэлектриком
Подстроечные воздушные
Конденсаторы и фильтры помехоподавляющие 
Сборки на основе конденсаторов"""

# группы из Sparv2006 пока без значений
