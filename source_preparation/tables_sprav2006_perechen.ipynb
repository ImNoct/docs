# %%
import pandas as pd

# %%
# интегральные микросхемы
path = 'tables/sprav2006/интегральные микросхемы/Перечень.csv'
df = pd.read_csv(path)
display(df)
# Out:
#      Номер серии ИС Типономинал ИС          Номер ТУ Технология  \
# 0               100       100ИВ165   И63.088.068ТУ19        NaN
# 1               100       100ИД161   И63.088.068ТУ11        NaN
# 2               100       100ИД162   И63.088.068ТУ11        NaN
# 3               100       100ИД164   И63.088.068ТУ11        NaN
# 4               100       100ИЕ136  И63.088.068-15ТУ        NaN
# ...             ...            ...               ...        ...
# 3750            820         820ХА6   бК0.347.018ТУ19        NaN
# 3751            842         842УЕ1     бК0.347.279ТУ        NaN
# 3752            843         843УР1     бК0.347.146ТУ        NaN
# 3753            851         851УН1     бК0.347.284ТУ        NaN
# 3754            851         851УН2     бК0.347.284ТУ        NaN
#
#       Количество элементов, бит (для ЗУ) Тип корпуса  \
# 0                                    277         NaN
# 1                                    141         NaN
# 2                                    141         NaN
# 3                                    159         NaN
# 4                                    424         NaN
# ...                                  ...         ...
# 3750                                 162         NaN
# 3751                                   5         NaN
# 3752                                 121         NaN
# 3753                                  20         NaN
# 3754                                  20         NaN
#
#                                  Группа  \
# 0      Микросхемы интегральные цифровые
# 1      Микросхемы интегральные цифровые
# 2      Микросхемы интегральные цифровые
# 3      Микросхемы интегральные цифровые
# 4      Микросхемы интегральные цифровые
# ...                                 ...
# 3750  Микросхемы интегральные гибридные
# 3751  Микросхемы интегральные гибридные
# 3752  Микросхемы интегральные гибридные
# 3753  Микросхемы интегральные гибридные
# 3754  Микросхемы интегральные гибридные
#
#                                               Подргуппа
# 0     Логические, арифметические, микропроцессоры и ...
# 1     Логические, арифметические, микропроцессоры и ...
# 2     Логические, арифметические, микропроцессоры и ...
# 3     Логические, арифметические, микропроцессоры и ...
# 4     Логические, арифметические, микропроцессоры и ...
# ...                                                 ...
# 3750                                                NaN
# 3751                                                NaN
# 3752                                                NaN
# 3753                                                NaN
# 3754                                                NaN
#
# [3755 rows x 8 columns]

# %%
# полупроводниковые приборы
path = 'tables/sprav2006/полупроводниковые приборы/Перечень.csv'
df = pd.read_csv(path)
display(df)
# Out:
#            Тип изделия                     Номер ТУ tпер.макс, °С tсниж, °С  \
# 0           Д214, А, Б                УЖ3.362.018ТУ            75         –
# 1           Д215, А, Б                УЖ3.362.018ТУ            75         –
# 2           Д231, А, Б                УЖ3.362.018ТУ            75         –
# 3           Д232, А, Б                УЖ3.362.018ТУ            75         –
# 4              Д233, Б                УЖ3.362.018ТУ            75         –
# ...                ...                          ...           ...       ...
# 1157    2ТС398А-1, Б-1                СБ0.336.063ТУ           135       105
# 1158  2ТС398А-1Н, Б-1Н  СБ0.336.063ТУ, РМ 11091.926           135       105
# 1159    2ТС398А94, Б94                аА0.339.632ТУ           135       105
# 1160   2ТС3136А-1, Б-1                аА0.339.345ТУ           125       100
# 1161       2ТС3103А, Б                аА0.339.031ТУ           175        55
#
#                                    Примечание  \
# 0     -60°С ≤ t ≤+75°С Iпр.ср.макс постоянный
# 1     -60°С ≤ t ≤+75°С Iпр.ср.макс постоянный
# 2     -60°С ≤ t ≤+75°С Iпр.ср.макс постоянный
# 3     -60°С ≤ t ≤+75°С Iпр.ср.макс постоянный
# 4     -60°С ≤ t ≤+75°С Iпр.ср.макс постоянный
# ...                                       ...
# 1157                                      NaN
# 1158                                      NaN
# 1159                                      NaN
# 1160                                      NaN
# 1161                                      NaN
#
#                                            СВЧ Диапазон  \
# 0     Приборы полупроводниковые, кроме приборов СВЧ ...
# 1     Приборы полупроводниковые, кроме приборов СВЧ ...
# 2     Приборы полупроводниковые, кроме приборов СВЧ ...
# 3     Приборы полупроводниковые, кроме приборов СВЧ ...
# 4     Приборы полупроводниковые, кроме приборов СВЧ ...
# ...                                                 ...
# 1157            Приборы полупроводниковые СВЧ диапазона
# 1158            Приборы полупроводниковые СВЧ диапазона
# 1159            Приборы полупроводниковые СВЧ диапазона
# 1160            Приборы полупроводниковые СВЧ диапазона
# 1161            Приборы полупроводниковые СВЧ диапазона
#
#                 Группа изделия     Подгруппа изделия
# 0      Диоды полупроводниковые  Диоды выпрямительные
# 1      Диоды полупроводниковые  Диоды выпрямительные
# 2      Диоды полупроводниковые  Диоды выпрямительные
# 3      Диоды полупроводниковые  Диоды выпрямительные
# 4      Диоды полупроводниковые  Диоды выпрямительные
# ...                        ...                   ...
# 1157  Сборки транзисторные СВЧ                   NaN
# 1158  Сборки транзисторные СВЧ                   NaN
# 1159  Сборки транзисторные СВЧ                   NaN
# 1160  Сборки транзисторные СВЧ                   NaN
# 1161  Сборки транзисторные СВЧ                   NaN
#
# [1162 rows x 8 columns]

# %%
df0 = df[['Группа изделия', 'Подгруппа изделия']]

# %%
df0.drop_duplicates()
# Out:
#                              Группа изделия  \
# 0                   Диоды полупроводниковые
# 64                  Диоды полупроводниковые
# 112                 Диоды полупроводниковые
# 124                 Диоды полупроводниковые
# 150                 Диоды полупроводниковые
# 156                            Стабилитроны
# 271                 Ограничители напряжения
# 299                         Генераторы шума
# 300       Транзисторы биполярные кремниевые
# 348       Транзисторы биполярные кремниевые
# 382       Транзисторы биполярные кремниевые
# 530         Сборки транзисторные кремниевые
# 534          Транзисторы полевые кремниевые
# 606   Транзисторы полевые арсенидогаллиевые
# 675                    Тиристоры кремниевые
# 699                               Диоды СВЧ
# 765                               Диоды СВЧ
# 781                               Диоды СВЧ
# 790                               Диоды СВЧ
# 851                               Диоды СВЧ
# 910                               Диоды СВЧ
# 976                         Транзисторы СВЧ
# 1057                        Транзисторы СВЧ
# 1154               Сборки транзисторные СВЧ
#
#                        Подгруппа изделия
# 0                   Диоды выпрямительные
# 64                      Диоды импульсные
# 112                Столбы выпрямительные
# 124                Варикапы подстроечные
# 150                       Сборки диодные
# 156                                  NaN
# 271                                  NaN
# 299                                  NaN
# 300                       Малой мощности
# 348                     Средней мощности
# 382                     Большой мощности
# 530                                  NaN
# 534                                  NaN
# 606                                  NaN
# 675                                  NaN
# 699                         Смесительные
# 765                          Детекторные
# 781                      Параметрические
# 790   Переключательные и ограничительные
# 851          Умножительные и настроечные
# 910                         Генераторные
# 976             Малой и средней мощности
# 1057                    Большой мощности
# 1154                                 NaN

# %%
# оптоэлектронные полупроводниковые приборы
path = 'tables/sprav2006/оптоэлектронные полупроводниковые приборы/Перечень.csv'
df = pd.read_csv(path)
display(df)

# %%
# изделия квантовой электроники

# %%
# генераторные, модуляторные, регулирующие лампы

# %%
# газоразрядные приборы и высоковольтные кенотроны

# %%
# трубки электроннолучевые приемные и преобразовательные

# %%
# знакосинтезирующие индикаторы

# %%
# приборы фотоэлектронные

# %%
# приборы фотоэлектрические

# %%
# приборы пьезоэлектрические и фильтры электромеханические

# %%
# резисторы

# %%
# конденсаторы

# %%
# трансформаторы

# %%
# дроссели

# %%
# линии задержки

# %%
# лампы накачки

# %%
# источники высокоинтенсивного оптического излучения

# %%
# компоненты волоконно-оптических систем передачи информации

# %%
# коммутационные изделия

# %%
# установочные изделия

# %%
# соединители низкочастотные и радиочастотные

# %%
# электровакуумные приборы и модули свч

# %%
# приборы ферритовые свч

# %%
# аппараты электрические низковольтные

# %%
# машины электрические малой мощности

# %%
# силовые полупроводниковые приборы

# %%
# кабели провода и шнуры электрические

# %%
# химические источники тока

# %%
# лампы электрические

# %%
# соединения

# %%
# платы с металлизированными сквозными отверстиями
